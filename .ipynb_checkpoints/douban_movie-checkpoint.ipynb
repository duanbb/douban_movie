# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
HEADER = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}
url_list = [
    'https://movie.douban.com/people/98909222/wish?start=0&sort=time&rating=all&filter=all&mode=list',
    'https://movie.douban.com/people/98909222/wish?start=30&sort=time&rating=all&filter=all&mode=list',
    #'https://movie.douban.com/people/98909222/wish?start=60&sort=time&rating=all&filter=all&mode=list'
]

# %%
def get_movie_info(movie_url):
    r_movie = requests.get(movie_url, headers=HEADER)
    soup_movie = BeautifulSoup(r_movie.text, 'html.parser')
    return {
        'name': str(soup_movie.find_all('span', {'property': 'v:itemreviewed'})[0].contents[0]),
        'year': int(soup_movie.find_all('span', {'class': 'year'})[0].contents[0].replace('(', '').replace(')', '')),
        'rating': float(soup_movie.find_all('strong', {'class': 'll rating_num', 'property': 'v:average'})[0].contents[0]),
        'votes': int(soup_movie.find_all('span', {'property': 'v:votes'})[0].contents[0])
    }

# %%
def get_page_info(url):
    r_page = requests.get(url, headers=HEADER)
    soup_page = BeautifulSoup(r_page.text, 'html.parser')  # 'lxml'
    movies = soup_page.find_all('div', {'class': 'title'})
    for i in range(0, len(movies)):
        movies_list.append(get_movie_info(movies[i].contents[1].attrs['href']))
        print('No. ' + str(i))
    del i

# %%
movies_list = []
for i in range(0, len(url_list)):
    get_page_info(url_list[i])
del i
# Out:
# No. 0
# No. 1
# No. 2
# No. 3
# No. 4
# No. 5
# No. 6
# No. 7
# No. 8
# No. 9
# No. 10
# No. 11
# No. 12
# No. 13
# No. 14
# No. 15
# No. 16
# No. 17
# No. 18
# No. 19
# No. 20
# No. 21
# No. 22
# No. 23
# No. 24
# No. 25
# No. 26
# No. 27
# No. 28
# No. 29
# No. 0
# No. 1
# No. 2
# No. 3
# No. 4
# No. 5
# No. 6
# No. 7
# No. 8
# No. 9
# No. 10
# No. 11
# No. 12
# No. 13
# No. 14
# No. 15
# No. 16
# No. 17
# No. 18
# No. 19
# No. 20
# No. 21
# No. 22
# No. 23

# %%
movies_df = pd.DataFrame(data=movies_list)
movies_df['rating_year'] = movies_df['rating'] * movies_df['year']
movies_df['rating_votes'] = movies_df['rating'] * movies_df['votes']
movies_df['rating_year_votes'] = movies_df['rating'] * movies_df['year'] * movies_df['votes']

# %%
pd.options.display.max_rows = None
movies_df.sort_values('rating_year_votes', ascending=False).reset_index()
# Out:
#     index                                        name  year  rating    votes  \
# 0      32                       头号玩家 Ready Player One  2018     8.7  1036640
# 1       2                           触不可及 Intouchables  2011     9.2   731806
# 2      50                            教父 The Godfather  1972     9.3   685347
# 3      49                   教父2 The Godfather: Part Ⅱ  1974     9.2   379934
# 4      23                                   雪国列车 설국열차  2013     7.5   334001
# 5      22        E.T. 外星人 E.T.: The Extra-Terrestrial  1982     8.6   264935
# 6      47                 教父3 The Godfather: Part III  1990     8.9   253625
# 7      44               华尔街之狼 The Wolf of Wall Street  2013     7.9   275677
# 8      17       侏罗纪世界2 Jurassic World: Fallen Kingdom  2018     6.7   315751
# 9      19                         绿里奇迹 The Green Mile  1999     8.8   206672
# 10     41                        奇幻森林 The Jungle Book  2016     7.8   220003
# 11     31  神探夏洛克：可恶的新娘 Sherlock: The Abominable Bride  2016     7.1   205657
# 12     27                      瞒天过海：美人计 Ocean's Eight  2018     6.7   209438
# 13      7                                     雨果 Hugo  2011     7.7   168878
# 14      8                          终结者 The Terminator  1984     8.1   161582
# 15     38                              徒手攀岩 Free Solo  2018     8.9   131855
# 16     30                流浪猫鲍勃 A Street Cat Named Bob  2016     8.0   144200
# 17      5                                  生死时速 Speed  1994     8.1    98910
# 18      4                                    盗火线 Heat  1995     8.5    91462
# 19      9                                     声之形 聲の形  2016     6.8   108837
# 20     28                       天使与魔鬼 Angels & Demons  2009     7.3    94006
# 21     14            回到未来2 Back to the Future Part II  1989     8.4    77217
# 22     11                   洛杉矶之战 Battle: Los Angeles  2011     6.1    97514
# 23     16                                 溺水小刀 溺れるナイフ  2016     7.6    75888
# 24      3           回到未来3 Back to the Future Part III  1990     8.4    66689
# 25     35                                别惹我 Malavita  2013     7.2    73647
# 26     40                             丧尸乐园 Zombieland  2009     7.3    71087
# 27     13                      铁娘子：坚固柔情 The Iron Lady  2011     7.6    65013
# 28     46                   福音战士新剧场版：破 ヱヴァンゲリヲン新劇場版：破  2009     9.3    51983
# 29     52                       摩纳哥王妃 Grace of Monaco  2014     6.8    67071
# 30     20                      世界之战 War of the Worlds  2005     6.6    69277
# 31     48                   福音战士新剧场版：序 ヱヴァンゲリヲン新劇場版：序  2007     9.1    47362
# 32     37    夺宝奇兵3 Indiana Jones and the Last Crusade  1989     8.2    52200
# 33      1    地心历险记 Journey to the Center of the Earth  2008     6.8    61900
# 34     39                  奥林匹斯的陷落 Olympus Has Fallen  2013     6.4    62632
# 35     42                           侠探杰克 Jack Reacher  2012     6.3    61122
# 36     53                        世界尽头 The World's End  2013     7.4    48021
# 37     26                     白雪公主之魔镜魔镜 Mirror Mirror  2012     6.1    57855
# 38     43                   福音战士新剧场版：Q ヱヴァンゲリヲン新劇場版：Q  2012     8.4    40605
# 39     10                  阿拉伯的劳伦斯 Lawrence of Arabia  1962     8.7    36043
# 40     21                      当怪物来敲门 A Monster Calls  2016     7.2    40268
# 41     25            黄昏双镖客 Per qualche dollaro in più  1965     8.8    29309
# 42     12                           绝地战警2 Bad Boys II  2003     7.5    30673
# 43      6                    哆啦A梦：大雄的金银岛 ドラえもん のび太の宝島  2018     6.5    33647
# 44     51                                   帕克 Parker  2013     6.5    32041
# 45     36                                 伊豆的舞女 伊豆の踊子  1974     8.6    19596
# 46     15                                        蛇形刁手  1978     7.1    15881
# 47     33                               间谍游戏 Spy Game  2001     6.9     8559
# 48      0         007之金枪人 The Man with the Golden Gun  1974     6.8     6191
# 49     18                 豪勇七蛟龙 The Magnificent Seven  1960     7.5     3628
# 50     45                    悬案密码2：野鸡杀手 Fasandræberne  2014     7.0     2681
# 51     34                                       潮骚 潮騒  1975     7.6     1112
# 52     29                        博格对战麦肯罗 Borg/McEnroe  2017     7.0     1073
# 53     24                             东京奥林匹克 東京オリンピック  1965     8.5      753
#
#     rating_year  rating_votes  rating_year_votes
# 0       17556.6     9018768.0       1.819987e+10
# 1       18501.2     6732615.2       1.353929e+10
# 2       18339.6     6373727.1       1.256899e+10
# 3       18160.8     3495392.8       6.899905e+09
# 4       15097.5     2505007.5       5.042580e+09
# 5       17045.2     2278441.0       4.515870e+09
# 6       17711.0     2257262.5       4.491952e+09
# 7       15902.7     2177848.3       4.384009e+09
# 8       13520.6     2115531.7       4.269143e+09
# 9       17591.2     1818713.6       3.635608e+09
# 10      15724.8     1716023.4       3.459503e+09
# 11      14313.6     1460164.7       2.943692e+09
# 12      13520.6     1403234.6       2.831727e+09
# 13      15484.7     1300360.6       2.615025e+09
# 14      16070.4     1308814.2       2.596687e+09
# 15      17960.2     1173509.5       2.368142e+09
# 16      16128.0     1153600.0       2.325658e+09
# 17      16151.4      801171.0       1.597535e+09
# 18      16957.5      777427.0       1.550967e+09
# 19      13708.8      740091.6       1.492025e+09
# 20      14665.7      686243.8       1.378664e+09
# 21      16707.6      648622.8       1.290111e+09
# 22      12267.1      594835.4       1.196214e+09
# 23      15321.6      576748.8       1.162726e+09
# 24      16716.0      560187.6       1.114773e+09
# 25      14493.6      530258.4       1.067410e+09
# 26      14665.7      518935.1       1.042541e+09
# 27      15283.6      494098.8       9.936327e+08
# 28      18683.7      483441.9       9.712348e+08
# 29      13695.2      456082.8       9.185508e+08
# 30      13233.0      457228.2       9.167425e+08
# 31      18263.7      430994.2       8.650054e+08
# 32      16309.8      428040.0       8.513716e+08
# 33      13654.4      420920.0       8.452074e+08
# 34      12883.2      400844.8       8.069006e+08
# 35      12675.6      385068.6       7.747580e+08
# 36      14896.2      355355.4       7.153304e+08
# 37      12273.2      352915.5       7.100660e+08
# 38      16900.8      341082.0       6.862570e+08
# 39      17069.4      313574.1       6.152324e+08
# 40      14515.2      289929.6       5.844981e+08
# 41      17292.0      257919.2       5.068112e+08
# 42      15022.5      230047.5       4.607851e+08
# 43      13117.0      218705.5       4.413477e+08
# 44      13084.5      208266.5       4.192405e+08
# 45      16976.4      168525.6       3.326695e+08
# 46      14043.8      112755.1       2.230296e+08
# 47      13806.9       59057.1       1.181733e+08
# 48      13423.2       42098.8       8.310303e+07
# 49      14700.0       27210.0       5.333160e+07
# 50      14098.0       18767.0       3.779674e+07
# 51      15010.0        8451.2       1.669112e+07
# 52      14119.0        7511.0       1.514969e+07
# 53      16702.5        6400.5       1.257698e+07

# %% [markdown]
# # 24	42	第一滴血 First Blood 8/1
# # 47	54	今夜在浪漫剧场 今夜、ロマンス劇場で 8/1
